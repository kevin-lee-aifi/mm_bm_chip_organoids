# %%
from scipy.stats import median_abs_deviation

import sys
sys.path.insert(0, '/home/workspace/mm_bm_chip_organoids')
sys.path.insert(0, '/home/workspace/')

from py_util import *
from utilities import *

hdir = '/home/workspace'
wdir = hdir + "/mm_bm_chip_organoids/EXP-01244"
objdir = wdir + "/processing/objects/"

adata = sc.read_h5ad(objdir + "wk4_adata.h5ad")

# %%
mono_cd14_markers = ["S100A9", "CCR2", "CD14", "FGR", "ITGAX", "CD34", "NCAM1", "ITGAM", "FCGR3A"]

sc.pl.umap(
    adata,
    color = mono_markers
)

# %%
markers = ["MPO", "CEBPA", "SPI1", "CEBPD", "CSF3R", "MKI67", "CD33", "CD38", "CD84"]

sc.pl.umap(
    adata,
    color = markers,
    vmin = 'p40',
    cmap='Reds'
)
