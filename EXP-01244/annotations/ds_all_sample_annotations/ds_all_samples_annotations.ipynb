# %%
from scipy.stats import median_abs_deviation

import sys
sys.path.insert(0, '/home/workspace/mm_bm_chip_organoids')
sys.path.insert(0, '/home/workspace/')

from py_util import *
from utilities import *

hdir = '/home/workspace'
wdir = hdir + "/mm_bm_chip_organoids/EXP-01244"
objdir = wdir + "/processing/objects/"

adata = sc.read_h5ad(objdir + "ds_all_samples_adata.h5ad")

# %%
sc.pl.umap(
    adata,
    color = 'sample_type',
    frameon = False,
)

# %%
CMP_markers = ["MPO", "CEBPA", "SPI1", "CEBPD", "CSF3R", "MKI67", "CD33", "CD38", "CD84"]
HPSC_markers = ["AVP", "MLLT3", "HLF", "CRHBP", "PROC"]

# %%
markers = ['IGLL1']

sc.pl.umap(
    adata,
    color = markers,
    frameon = False,
    cmap = 'Reds',
    # vmax = 'p95'
)

sc.pl.umap(
    adata[adata.obs['sample_type'] == 'week2'],
    color = markers,
    frameon = False,
    cmap = 'Reds',
    # vmax = 'p95'
)

sc.pl.umap(
    adata[adata.obs['sample_type'] == 'week3'],
    color = markers,
    frameon = False,
    cmap = 'Reds',
    # vmax = 'p95'
)

sc.pl.umap(
    adata[adata.obs['sample_type'] == 'week4'],
    color = markers,
    frameon = False,
    cmap = 'Reds',
    # vmax = 'p95'
)

sc.pl.umap(
    adata[adata.obs['sample_type'] == 'bm'],
    color = markers,
    frameon = False,
    cmap = 'Reds',
    # vmax = 'p95'
)

sc.pl.umap(
    adata[adata.obs['sample_type'] == 'msc'],
    color = markers,
    frameon = False,
    cmap = 'Reds',
    # vmax = 'p95'
)
