# %%
from scipy.stats import median_abs_deviation

import sys
sys.path.insert(0, '/home/workspace/mm_analysis')
sys.path.insert(0, '/home/workspace/')

from py_util import *
from utilities import *

hdir = '/home/workspace'
wdir = hdir + "/mm_analysis/EXP-01244"
objdir = wdir + "/processing/objects/"
degdir = wdir + "/deg_list/"

adata = sc.read_h5ad(objdir + "downsampled_processed_all_organoids_adata.h5ad")

labels = pd.read_csv(hdir + "/mm_analysis/bm_cell_label_reference.csv")
labels = labels.iloc[10:13, 1:5]

exclude = ['CD16', 'GKMZ', 'HLA-DRA', 'ILRB2', 'ITGAE', 'STI4', 'VPREB2']

markers = {
    celltype: genes.split(", ")
    for celltype, genes in zip(labels.iloc[:, 1], labels.iloc[:, 2])
}

markers = {
    celltype: [gene for gene in genes if gene not in exclude]
    for celltype, genes in markers.items()
}

markers
# Out:
# {'mono_cd14': ['S100A9',
#   'CCR2',
#   'CD14',
#   'FGR',
#   'ITGAX',
#   'CD34',
#   'NCAM1',
#   'ITGAM',
#   'FCGR3A'],
#  'mono_cd16': ['FCGR3A', 'IRF8', 'LY86', 'LST1', 'CD34', 'CD14'],
#  'mono_intermediate': ['CCR5', 'FCGR3A', 'CD14', 'CD86']}

# %%
sc.pl.umap(
    adata,
    color='name'
)

# %%
celltype = 'mono_cd14'

fig = sc.pl.umap(
    adata,
    color=markers[celltype],
    vmax='p99',
    show=False,
    return_fig=True
)

fig.suptitle(f'{celltype} markers', y=.93, fontweight='bold')
# Out:
# Text(0.5, 0.93, 'mono_cd14 markers')

# %%
celltype = 'mono_cd16'

fig = sc.pl.umap(
    adata,
    color=markers[celltype],
    vmax='p99',
    show=False,
    return_fig=True
)

fig.suptitle(f'{celltype} markers', y=0.97, fontweight='bold')
# Out:
# Text(0.5, 0.97, 'mono_cd16 markers')

# %%
celltype = 'mono_intermediate'

fig = sc.pl.umap(
    adata,
    color=markers[celltype],
    vmax='p99',
    show=False,
    return_fig=True
)

fig.suptitle(f'{celltype} markers', y=1.05, fontweight='bold')
# Out:
# Text(0.5, 1.05, 'mono_intermediate markers')
