# %%
from scipy.stats import median_abs_deviation

import sys
sys.path.insert(0, '/home/workspace/mm_bm_chip_organoids')
sys.path.insert(0, '/home/workspace/')

from py_util import *
from utilities import *

hdir = '/home/workspace'
wdir = hdir + "/mm_bm_chip_organoids/EXP-01440"
objdir1 = wdir + "/object_building/objects/"
objdir2 = wdir + "/quality_control/objects/"

# %% [markdown]
# ### Generating QC labeled, unfiltered, processed adata

# %%
cr_outs_path = wdir + "/cr_outs"
path = wdir + "/sample_reference.csv"
df = pd.read_csv(path)

sample_dict = {name: donor for name, donor in zip(df.iloc[:, 0], df.iloc[:, 4])}

type_dict = {name: sample_type for name, sample_type in zip(df.iloc[:, 0], df.iloc[:, 2])}

h5_paths = [os.path.join(root, 'sample_filtered_feature_bc_matrix.h5') 
           for root, _, files in os.walk(cr_outs_path) 
           if 'sample_filtered_feature_bc_matrix.h5' in files]

adatas = {}

for path in h5_paths:
    name = path.split('per_sample_outs/')[1].split('/')[0]
    
    adata = sc.read_10x_h5(path)
    adata.var_names_make_unique()

    adata.obs['sample'] = name
    adata.obs['donor'] = adata.obs['sample'].replace(sample_dict)
    adata.obs['type'] = adata.obs['sample'].replace(type_dict)

    adata.var["mt"] = adata.var_names.str.startswith("MT-")                 # mitochondrial genes
    adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL"))      # ribosomal genes
    adata.var["hb"] = adata.var_names.str.contains(("^HB[^(P)]"))           # hemoglobin genes

    sc.pp.calculate_qc_metrics(adata, qc_vars=["mt", "ribo", "hb"], inplace=True, percent_top=[20], log1p=True)
    
    adata.obs["outlier"] = (
        is_outlier(adata, "log1p_total_counts", 5)                # calling outlier cells with log1p_total_counts greater than 5 MAD's
        | is_outlier(adata, "log1p_n_genes_by_counts", 5)         # calling outlier cells with log1p_n_genes_by_counts greater than 5 MAD's
        | is_outlier(adata, "pct_counts_in_top_20_genes", 5)      # calling outlier cells with pct_counts_in_top_20_genes greater than 5 MAD's
    )
    
    # Call mt outlier cells with pct_counts_mt greater than 3 MAD's
    adata.obs["mt_outlier"] = is_outlier(adata, "pct_counts_mt", 3)

    print(f"Shape of adata.X: {adata.X.shape}")
    
    # # Run Scrublet for doublet detection
    scrub = scrublet.Scrublet(adata.X)
    doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose=False)
    
    # # Add Scrublet results to cell metadata
    # adata.obs['doublet_score'] = doublet_scores
    # adata.obs['predicted_doublet'] = predicted_doublets
    
    # # Store log1p transformed normalized counts
    # sc.pp.normalize_total(adata)
    # sc.pp.log1p(adata)
    
    # # Saving raw adata
    # adata.raw = adata
    
    # # Standard processing workflow
    # sc.pp.highly_variable_genes(adata)
    # sc.pp.pca(adata)
    # sc.pp.neighbors(adata)
    # sc.tl.umap(adata)
    
    # # Computing a range of leiden resolutions from 0-2 in increments of 0.1
    # res_range = np.round(np.arange(0, 2.2, 0.1), 1)
    # for res in res_range:
    #     sc.tl.leiden(
    #         adata, 
    #         flavor="igraph",
    #         key_added=f"leiden_{str(res).replace('.', '_')}",
    #         n_iterations=2,
    #         resolution=res
    #     )
    
    # adata.uns['leiden_ranges'] = [f'leiden_{i:.1f}'.replace('.', '_') for i in np.arange(0, 2.1, 0.1)]

    # adatas[name] = adata.copy()
# Out:
# Shape of adata.X: (8365, 18082)
# (8365, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 44
#      42 # # Run Scrublet for doublet detection
#      43 scrub = scrublet.Scrublet(adata.X)
# ---> 44 doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose=False)
#      46 # # Add Scrublet results to cell metadata
#      47 # adata.obs['doublet_score'] = doublet_scores
#      48 # adata.obs['predicted_doublet'] = predicted_doublets
#    (...)
#      75
#      76 # adatas[name] = adata.copy()
#
# File ~/environment/mm_py_env/lib/python3.9/site-packages/scrublet/scrublet.py:237, in Scrublet.scrub_doublets(self, synthetic_doublet_umi_subsampling, use_approx_neighbors, distance_metric, get_doublet_neighbor_parents, min_counts, min_cells, min_gene_variability_pctl, log_transform, mean_center, normalize_variance, n_prin_comps, svd_solver, verbose)
#     235 if mean_center:
#     236     print_optional('Embedding transcriptomes using PCA...', verbose)
# --> 237     pipeline_pca(self, n_prin_comps=n_prin_comps, random_state=self.random_state, svd_solver=svd_solver)
#     238 else:
#     239     print_optional('Embedding transcriptomes using Truncated SVD...', verbose)
#
# File ~/environment/mm_py_env/lib/python3.9/site-packages/scrublet/helper_functions.py:91, in pipeline_pca(self, n_prin_comps, random_state, svd_solver)
#      87     X_sim = self._E_sim_norm
#      89 print(self._E_obs_norm.shape)
# ---> 91 pca = PCA(n_components=n_prin_comps, random_state=random_state, svd_solver=svd_solver).fit(X_obs)
#      92 self.set_manifold(pca.transform(X_obs), pca.transform(X_sim))
#      93 return
#
# File ~/environment/mm_py_env/lib/python3.9/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/environment/mm_py_env/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:442, in PCA.fit(self, X, y)
#     424 @_fit_context(prefer_skip_nested_validation=True)
#     425 def fit(self, X, y=None):
#     426     """Fit the model with X.
#     427
#     428     Parameters
#    (...)
#     440         Returns the instance itself.
#     441     """
# --> 442     self._fit(X)
#     443     return self
#
# File ~/environment/mm_py_env/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:544, in PCA._fit(self, X)
#     542     return self._fit_full(X, n_components, xp, is_array_api_compliant)
#     543 elif self._fit_svd_solver in ["arpack", "randomized"]:
# --> 544     return self._fit_truncated(X, n_components, xp)
#
# File ~/environment/mm_py_env/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:719, in PCA._fit_truncated(self, X, n_components, xp)
#     714     raise ValueError(
#     715         "n_components=%r cannot be a string with svd_solver='%s'"
#     716         % (n_components, svd_solver)
#     717     )
#     718 elif not 1 <= n_components <= min(n_samples, n_features):
# --> 719     raise ValueError(
#     720         "n_components=%r must be between 1 and "
#     721         "min(n_samples, n_features)=%r with "
#     722         "svd_solver='%s'"
#     723         % (n_components, min(n_samples, n_features), svd_solver)
#     724     )
#     725 elif svd_solver == "arpack" and n_components == min(n_samples, n_features):
#     726     raise ValueError(
#     727         "n_components=%r must be strictly less than "
#     728         "min(n_samples, n_features)=%r with "
#     729         "svd_solver='%s'"
#     730         % (n_components, min(n_samples, n_features), svd_solver)
#     731     )
#
# ValueError: n_components=30 must be between 1 and min(n_samples, n_features)=2 with svd_solver='arpack'

# %%
cr_outs_path = os.path.join(hdir, "mm_bm_chip_organoids/EXP-01244/cr_outs")

qc_dict = {
    "CELL00911": "msc_qc_adata",
    "BMC07965-007": "bm_qc_adata",
    "OR00001": "week4_qc_adata",
    "OR07965-02": "week3_qc_adata",
    "OR07965-01": "week2_qc_adata"
}

def generate_qc_adata(sample_name, output_name):
    
    # Dictionary mapping user-friendly sample names to their corresponding IDs
    sample_dict = {
       'week2': "OR07965-01",    
       'week3': "OR07965-02", 
       'week4': "OR00001",
       'bm': "BMC07965-007",
       'msc': "CELL00911"
    }
    
    name_dict = {
       'week2': "Week 2",
       'week3': "Week 3", 
       'week4': "Week 4",
       'bm': "BMMC Start Sample",
       'msc': "MSC Start Sample"   
    }
    
    # Create reverse mapping from sample IDs to their user-friendly names
    id_to_sample = {v: k for k, v in sample_dict.items()}
    
    # Find all filtered_feature_bc_matrix.h5 files in the directory structure
    h5_paths = [os.path.join(root, 'sample_filtered_feature_bc_matrix.h5') 
               for root, _, files in os.walk(cr_outs_path) 
               if 'sample_filtered_feature_bc_matrix.h5' in files]
    
    # Get only the msc starter h5 paths
    paths = [path for path in h5_paths if sample_name in path]
    
    # Dictionary to store AnnData objects for each sample
    adatas = {}

    print(paths)
    
    # Process each H5 file
    for path in paths:
        # Extract sample name from path
        name = path.split('per_sample_outs/')[1].split('/')[0]
        
        # Read the H5 file and create AnnData object
        adata = sc.read_10x_h5(path)
        adata.var_names_make_unique()
    
        adata.obs['sample'] = name
    
        adata.obs['base_sample'] = adata.obs['sample'].str.replace(r'_\d+$', '', regex=True)      # Add metadata column for batched replicates
        adata.obs['sample_type'] = adata.obs['base_sample'].replace(id_to_sample)                 # Add sample names (week2, week3, etc.)
        adata.obs['name'] = adata.obs['sample_type'].replace(name_dict)                           # Add pretty names (Week 2, Week 3, etc.)
    
        adatas[name] = adata.copy()
    
    adata = ad.concat(adatas.values(), join='outer', merge='same')
    
    adata.var["mt"] = adata.var_names.str.startswith("MT-")                 # mitochondrial genes
    adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL"))      # ribosomal genes
    adata.var["hb"] = adata.var_names.str.contains(("^HB[^(P)]"))           # hemoglobin genes
    
    sc.pp.calculate_qc_metrics(adata, qc_vars=["mt", "ribo", "hb"], inplace=True, percent_top=[20], log1p=True)
    
    adata.obs["outlier"] = (
        is_outlier(adata, "log1p_total_counts", 5)                # calling outlier cells with log1p_total_counts greater than 5 MAD's
        | is_outlier(adata, "log1p_n_genes_by_counts", 5)         # calling outlier cells with log1p_n_genes_by_counts greater than 5 MAD's
        | is_outlier(adata, "pct_counts_in_top_20_genes", 5)      # calling outlier cells with pct_counts_in_top_20_genes greater than 5 MAD's
    )
    
    # Call mt outlier cells with pct_counts_mt greater than 3 MAD's
    adata.obs["mt_outlier"] = is_outlier(adata, "pct_counts_mt", 3)
    
    # Run Scrublet for doublet detection
    scrub = scrublet.Scrublet(adata.X)
    doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose=False)
    
    # Add Scrublet results to cell metadata
    adata.obs['doublet_score'] = doublet_scores
    adata.obs['predicted_doublet'] = predicted_doublets
    
    # Store log1p transformed normalized counts
    sc.pp.normalize_total(adata)
    sc.pp.log1p(adata)
    
    # Saving raw adata
    adata.raw = adata
    
    # Standard processing workflow
    sc.pp.highly_variable_genes(adata)
    sc.pp.pca(adata)
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)
    
    # Computing a range of leiden resolutions from 0-2 in increments of 0.1
    res_range = np.round(np.arange(0, 2.2, 0.1), 1)
    for res in res_range:
        sc.tl.leiden(
            adata, 
            flavor="igraph",
            key_added=f"leiden_{str(res).replace('.', '_')}",
            n_iterations=2,
            resolution=res
        )
    
    adata.uns['leiden_ranges'] = [f'leiden_{i:.1f}'.replace('.', '_') for i in np.arange(0, 2.1, 0.1)]
    
    adata.write(objdir + f'{output_name}.h5ad', compression='gzip')

    return adata 

for name, output in qc_dict.items():
    generate_qc_adata(sample_name = name, output_name = output)
# Out:
# ['/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/CELL00911/count/sample_filtered_feature_bc_matrix.h5']
# ... storing 'sample' as categorical
# ... storing 'base_sample' as categorical
# ... storing 'sample_type' as categorical
# ... storing 'name' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ['/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/BMC07965-007_1/count/sample_filtered_feature_bc_matrix.h5', '/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/BMC07965-007_2/count/sample_filtered_feature_bc_matrix.h5', '/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/BMC07965-007_3/count/sample_filtered_feature_bc_matrix.h5']
# ... storing 'sample' as categorical
# ... storing 'base_sample' as categorical
# ... storing 'sample_type' as categorical
# ... storing 'name' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ['/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/OR00001_2/count/sample_filtered_feature_bc_matrix.h5', '/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/OR00001_3/count/sample_filtered_feature_bc_matrix.h5', '/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/OR00001_1/count/sample_filtered_feature_bc_matrix.h5']
# ... storing 'sample' as categorical
# ... storing 'base_sample' as categorical
# ... storing 'sample_type' as categorical
# ... storing 'name' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ['/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/OR07965-02/count/sample_filtered_feature_bc_matrix.h5']
# ... storing 'sample' as categorical
# ... storing 'base_sample' as categorical
# ... storing 'sample_type' as categorical
# ... storing 'name' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ['/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/OR07965-01_1/count/sample_filtered_feature_bc_matrix.h5', '/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/OR07965-01_3/count/sample_filtered_feature_bc_matrix.h5', '/home/workspace/mm_bm_chip_organoids/EXP-01244/cr_outs/outs/per_sample_outs/OR07965-01_2/count/sample_filtered_feature_bc_matrix.h5']
# ... storing 'sample' as categorical
# ... storing 'base_sample' as categorical
# ... storing 'sample_type' as categorical
# ... storing 'name' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical

# %% [markdown]
# ### UMI's per cell

# %%
metrics = [
    "n_genes_by_counts",
    "total_counts",
    "pct_counts_in_top_20_genes",
    "total_counts_mt",
    "pct_counts_mt",
    "total_counts_ribo",
    "pct_counts_ribo",
    "total_counts_hb",
    "pct_counts_hb",
    "doublet_score",
    "predicted_doublet"
]
# Out:
# AnnData object with n_obs × n_vars = 49435 × 18082
#     obs: 'sample', 'base_sample', 'sample_type', 'name', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'mt_outlier', 'doublet_score', 'predicted_doublet', 'leiden_0_0', 'leiden_0_1', 'leiden_0_2', 'leiden_0_3', 'leiden_0_4', 'leiden_0_5', 'leiden_0_6', 'leiden_0_7', 'leiden_0_8', 'leiden_0_9', 'leiden_1_0', 'leiden_1_1', 'leiden_1_2', 'leiden_1_3', 'leiden_1_4', 'leiden_1_5', 'leiden_1_6', 'leiden_1_7', 'leiden_1_8', 'leiden_1_9', 'leiden_2_0', 'leiden_2_1'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb'
#     uns: 'sample_type_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ### Doublets

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 6))

metric = "doublet_score"

sc.pl.violin(
    adata,
    keys=metric,
    groupby='sample_type',
    show=False,
    ax=ax
)

samples = list(adata.obs['sample_type'].unique())

for i, sample in enumerate(samples):
    mask = adata.obs['sample_type'] == sample
    data = adata[mask].obs[metric]
    median = np.median(data)
    q3 = np.quantile(data, 0.95)

    if i == 0:
        median_y_label_offset = median * 0.3
        q3_y_label_offset = q3 * 0.4
        median_x_label_offset = median * 2
        q3_x_label_offset = q3 * 2.3
    
    ax.text(i + median_x_label_offset, median + q3_y_label_offset, f'{median:.2f}', ha='left', va='top')
    ax.text(i - q3_x_label_offset, q3 + q3_y_label_offset, f'{q3:.2f}', ha='left', va='top')
    
    ax.hlines(median, xmin=i-0.2, xmax=i+0.2, color='red', linestyle='--', label='Median' if i == 0 else '')
    ax.hlines(q3, xmin=i-0.2, xmax=i+0.2, color='blue', linestyle=':', label='Q3' if i == 0 else '')

fig.suptitle(f'{metric}')

ax.legend()

# %% [markdown]
# ### Mitochondrial UMI's

# %%
fig, ax = plt.subplots(1, 1)

metric = 'pct_counts_mt'

sc.pl.violin(
    adata,
    keys=metric,
    groupby='sample_type',
    show=False,
    ax=ax
)

samples = list(adata.obs['sample_type'].unique())

for i, sample in enumerate(samples):
    mask = adata.obs['sample_type'] == sample
    num = sum(adata[mask].obs[metric] >= 10)
    
    ax.text(i + 0.15, 16, f'{num}', ha='left', va='top')

ax.axhline(10, xmin=0, xmax=5, color='red', label='10% counts mt')

fig.suptitle('# of cells above 10% counts mt')

ax.legend()

# %% [markdown]
# ### Hemoglobin counts

# %%
fig, ax = plt.subplots(1, 1)

metric = 'pct_counts_hb'

sc.pl.violin(
    adata,
    keys=metric,
    groupby='sample_type',
    show=False,
    ax=ax
)

samples = list(adata.obs['sample_type'].unique())

for i, sample in enumerate(samples):
    mask = adata.obs['sample_type'] == sample
    num = sum(adata[mask].obs[metric] >= 10)
    
    ax.text(i + 0.15, 17, f'{num}', ha='left', va='top')

ax.axhline(10, xmin=0, xmax=5, color='red', label='10% counts hb')

fig.suptitle('# of cells above 10% counts hb')

ax.legend()

# %% [markdown]
# ### Percent counts in top 20 genes

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 6))

metric = 'pct_counts_in_top_20_genes'

sc.pl.violin(
    adata,
    keys=metric,
    groupby='sample_type',
    show=False,
    ax=ax
)

samples = list(adata.obs['sample_type'].unique())

for i, sample in enumerate(samples):
    mask = adata.obs['sample_type'] == sample
    data = adata[mask].obs['pct_counts_in_top_20_genes']
    median = np.median(data)
    q3 = np.quantile(data, 0.95)
    
    ax.text(i + 0.125, median - 2, f'{median:.2f}', ha='left', va='top')
    ax.text(i - 0.475, q3 + 7, f'{q3:.2f}', ha='left', va='top')
    
    ax.hlines(median, xmin=i-0.2, xmax=i+0.2, color='red', linestyle='--', label='Median' if i == 0 else '')
    ax.hlines(q3, xmin=i-0.2, xmax=i+0.2, color='blue', linestyle=':', label='Q3' if i == 0 else '')

fig.suptitle('Median and Q3 of "pct_counts_in_top_20_genes"')

ax.legend()
